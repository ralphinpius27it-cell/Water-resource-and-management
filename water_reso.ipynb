# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import random
import time
import csv
from datetime import datetime
import matplotlib.pyplot as plt

# File to store water usage logs
FILE_NAME = "water_usage.csv"

# Thresholds
MAX_USAGE_PER_MIN = 5       # liters per minute (normal max flow)
LEAK_DETECTION_THRESHOLD = 0.5  # flow when no usage expected (leak)

# Function to simulate sensor readings
def get_water_flow():
    # Random water flow (liters/min) simulation
    # 70% of time = normal use (0-5 L/min), 20% leak, 10% high flow
    rand = random.random()
    if rand < 0.7:
        return round(random.uniform(0, 5), 2)
    elif rand < 0.9:
        return round(random.uniform(0.1, 0.8), 2)  # Leak
    else:
        return round(random.uniform(5, 10), 2)  # High abnormal usage

# Function to log water usage
def log_data(flow_rate):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(FILE_NAME, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([timestamp, flow_rate])

# Function to check leak or abnormal usage
def check_alert(flow_rate):
    if flow_rate > MAX_USAGE_PER_MIN:
        print(f"⚠️ ALERT: Abnormally high water usage detected! ({flow_rate} L/min)")
    elif 0 < flow_rate < LEAK_DETECTION_THRESHOLD:
        print(f"💧 ALERT: Possible leakage detected! ({flow_rate} L/min)")

# Function to visualize data
def plot_usage():
    timestamps = []
    flow_rates = []

    with open(FILE_NAME, "r") as file:
        reader = csv.reader(file)
        for row in reader:
            if row:  # skip empty rows
                timestamps.append(row[0])
                flow_rates.append(float(row[1]))

    plt.figure(figsize=(10, 5))
    plt.plot(timestamps, flow_rates, marker='o', linestyle='-', label="Water Flow (L/min)")
    plt.xticks(rotation=45)
    plt.xlabel("Time")
    plt.ylabel("Water Flow (L/min)")
    plt.title("Smart Water Monitoring System")
    plt.legend()
    plt.tight_layout()
    plt.show()

# ------------------ MAIN ------------------
print("Starting Smart Water Monitoring System...\n")

# Create CSV with headers if not exists
try:
    with open(FILE_NAME, "x", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Timestamp", "FlowRate(L/min)"])
except FileExistsError:
    pass

# Simulate readings for 20 cycles
for i in range(20):
    flow = get_water_flow()
    print(f"[{i+1}] Flow Rate: {flow} L/min")
    log_data(flow)
    check_alert(flow)
    time.sleep(1)  # 1 second delay (instead of real 1 min for demo)

print("\nSimulation completed. Generating graph...")
plot_usage()
# Out:
# Starting Smart Water Monitoring System...
#
# [1] Flow Rate: 1.26 L/min
# [2] Flow Rate: 1.61 L/min
# [3] Flow Rate: 2.44 L/min
# [4] Flow Rate: 7.3 L/min
# ⚠️ ALERT: Abnormally high water usage detected! (7.3 L/min)
# [5] Flow Rate: 4.56 L/min
# [6] Flow Rate: 3.56 L/min
# [7] Flow Rate: 1.33 L/min
# [8] Flow Rate: 2.62 L/min
# [9] Flow Rate: 0.47 L/min
# 💧 ALERT: Possible leakage detected! (0.47 L/min)
# [10] Flow Rate: 2.99 L/min
# [11] Flow Rate: 1.55 L/min
# [12] Flow Rate: 1.97 L/min
# [13] Flow Rate: 2.48 L/min
# [14] Flow Rate: 7.57 L/min
# ⚠️ ALERT: Abnormally high water usage detected! (7.57 L/min)
# [15] Flow Rate: 5.42 L/min
# ⚠️ ALERT: Abnormally high water usage detected! (5.42 L/min)
# [16] Flow Rate: 0.43 L/min
# 💧 ALERT: Possible leakage detected! (0.43 L/min)
# [17] Flow Rate: 2.27 L/min
# [18] Flow Rate: 0.78 L/min
# [19] Flow Rate: 4.48 L/min
# [20] Flow Rate: 3.2 L/min
#
# Simulation completed. Generating graph...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-149261332.py in <cell line: 0>()
#      80
#      81 print("\nSimulation completed. Generating graph...")
# ---> 82 plot_usage()
#
# /tmp/ipython-input-149261332.py in plot_usage()
#      48             if row:  # skip empty rows
#      49                 timestamps.append(row[0])
# ---> 50                 flow_rates.append(float(row[1]))
#      51
#      52     plt.figure(figsize=(10, 5))
#
# ValueError: could not convert string to float: 'FlowRate(L/min)'
